# %%
import pandas as pd

# %%
data_frame = pd.read_csv("Zillow-Property-Listing-Info.csv")

# %%
data_frame
# Out:
#            zpid      city state     homeStatus  \
# 0     244761651  New York    NY          OTHER
# 1    2113022086  New York    NY          OTHER
# 2    2101917848  New York    NY          OTHER
# 3    2101574753  New York    NY          OTHER
# 4    2112993954  New York    NY          OTHER
# ..          ...       ...   ...            ...
# 995   338435597  New York    NY       FOR_SALE
# 996    31527049  New York    NY  RECENTLY_SOLD
# 997    31527319  New York    NY  RECENTLY_SOLD
# 998    80010054  New York    NY  RECENTLY_SOLD
# 999   219707044  New York    NY  RECENTLY_SOLD
#
#                                                address  \
# 0    {"city":"New York","state":"NY","streetAddress...
# 1    {"city":"New York","state":"NY","streetAddress...
# 2    {"city":"New York","state":"NY","streetAddress...
# 3    {"city":"New York","state":"NY","streetAddress...
# 4    {"city":"New York","state":"NY","streetAddress...
# ..                                                 ...
# ...

# %%
# Data Exploration by listing the different columns

# %%
list(data_frame.columns)
# Out:
# ['zpid',
#  'city',
#  'state',
#  'homeStatus',
#  'address',
#  'isListingClaimedByCurrentSignedInUser',
#  'isCurrentSignedInAgentResponsible',
#  'bedrooms',
#  'bathrooms',
#  'price',
#  'yearBuilt',
#  'streetAddress',
#  'zipcode',
#  'isCurrentSignedInUserVerifiedOwner',
#  'isVerifiedClaimedByCurrentSignedInUser',
#  'listingDataSource',
#  'longitude',
#  'latitude',
#  'hasBadGeocode',
#  'streetViewMetadataUrlMediaWallLatLong',
#  'streetViewMetadataUrlMediaWallAddress',
#  'streetViewServiceUrl',
#  'livingArea',
#  'homeType',
#  'lotSize',
#  'lotAreaValue',
#  'lotAreaUnits',
#  'livingAreaValue',
#  'livingAreaUnitsShort',
#  'isUndisclosedAddress',
#  'zestimate',
#  'rentZestimate',
#  'currency',
#  'hideZestimate',
#  'dateSoldString',
#  'taxAssessedValue',
#  'taxAssessedYear',
#  'country',
#  'propertyTaxRate',
#  'photoCount',
#  'isPremierBuilder',
#  'isZillowOwned',
#  'ssid',
#  'hdpUrl',
#  'tourViewCount',
#  'hasPublicVideo',
#  'lastSoldPrice',
# ...

# %%
# zpid, streetAddress, longitude, latitude, zestimate, RentZestimate are the features that will be looked at.
